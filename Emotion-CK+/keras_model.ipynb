# %%
import numpy as np
import pandas as pd 
import os,cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import keras

from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization
import os
print(os.listdir("ckplus/"))
# Out:
# ['disgust', 'anger', 'happy', 'contempt', 'sadness', 'fear', 'surprise']

# %%
data_path = 'ckplus/'
data_dir_list = os.listdir(data_path)

img_rows=256
img_cols=256
num_channel=1

num_epoch=10

img_data_list=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        input_img_resize=cv2.resize(input_img,(48,48))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-disgust
#
# Loaded the images of dataset-anger
#
# Loaded the images of dataset-happy
#
# Loaded the images of dataset-contempt
#
# Loaded the images of dataset-sadness
#
# Loaded the images of dataset-fear
#
# Loaded the images of dataset-surprise
# (981, 48, 48, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:134]=0 #135
labels[135:188]=1 #54
labels[189:365]=2 #177
labels[366:440]=3 #75
labels[441:647]=4 #207
labels[648:731]=5 #84
labels[732:980]=6 #249

names = ['anger','contempt','disgust','fear','happy','sadness','surprise']

def getLabel(id):
    return ['anger','contempt','disgust','fear','happy','sadness','surprise'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)

x,y = shuffle(img_data,Y, random_state=2)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.15, random_state=2)
x_test=X_test

# %%
input_shape=(48,48,3)

model = Sequential()
model.add(Conv2D(6, (5, 5), input_shape=input_shape, padding='same', activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(16, (5, 5), padding='same', activation = 'relu'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation = 'relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(128, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation = 'softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'],optimizer='adam')

# %%
model.summary()
model.get_config()
model.layers[0].get_config()
model.layers[0].input_shape
model.layers[0].output_shape
model.layers[0].get_weights()
np.shape(model.layers[0].get_weights()[0])
model.layers[0].trainable
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 48, 48, 6)         456
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 24, 24, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 24, 24, 16)        2416
# _________________________________________________________________
# activation (Activation)      (None, 24, 24, 16)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 10, 64)        9280
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               204928
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 217,983
# Trainable params: 217,983
# Non-trainable params: 0
# _________________________________________________________________
# True

# %%
from keras import callbacks
filename='model_train_new.csv'
filepath="Best-weights-my_model-{epoch:03d}-{loss:.4f}-{acc:.4f}.hdf5"

csv_log=callbacks.CSVLogger(filename, separator=',', append=False)
checkpoint = callbacks.ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')
callbacks_list = [csv_log,checkpoint]
callbacks_list = [csv_log]

# %%
hist = model.fit(X_train, y_train, batch_size=7, epochs=50, verbose=1, validation_data=(X_test, y_test),callbacks=callbacks_list)
# Out:
# Epoch 1/50
# 119/119 [==============================] - 3s 21ms/step - loss: 1.8649 - accuracy: 0.2509 - val_loss: 1.8121 - val_accuracy: 0.4189
# Epoch 2/50
# 119/119 [==============================] - 2s 17ms/step - loss: 1.6619 - accuracy: 0.3758 - val_loss: 1.1910 - val_accuracy: 0.5068
# Epoch 3/50
# 119/119 [==============================] - 2s 14ms/step - loss: 1.3213 - accuracy: 0.5114 - val_loss: 0.9913 - val_accuracy: 0.6959
# Epoch 4/50
# 119/119 [==============================] - 2s 14ms/step - loss: 1.0998 - accuracy: 0.5834 - val_loss: 0.8343 - val_accuracy: 0.6554
# Epoch 5/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.9129 - accuracy: 0.6555 - val_loss: 0.7174 - val_accuracy: 0.6892
# Epoch 6/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.7848 - accuracy: 0.6939 - val_loss: 0.7010 - val_accuracy: 0.7500
# Epoch 7/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.7325 - accuracy: 0.7191 - val_loss: 0.6328 - val_accuracy: 0.7365
# Epoch 8/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.6477 - accuracy: 0.7407 - val_loss: 0.5796 - val_accuracy: 0.7838
# Epoch 9/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.5984 - accuracy: 0.7695 - val_loss: 0.5857 - val_accuracy: 0.7432
# Epoch 10/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.5548 - accuracy: 0.7887 - val_loss: 0.5963 - val_accuracy: 0.7500
# Epoch 11/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.5189 - accuracy: 0.8055 - val_loss: 0.6159 - val_accuracy: 0.7635
# Epoch 12/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.5203 - accuracy: 0.7911 - val_loss: 0.6851 - val_accuracy: 0.7770
# Epoch 13/50
# 119/119 [==============================] - 2s 16ms/step - loss: 0.4904 - accuracy: 0.8055 - val_loss: 0.6119 - val_accuracy: 0.7635
# Epoch 14/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.4632 - accuracy: 0.8067 - val_loss: 0.5783 - val_accuracy: 0.7770
# Epoch 15/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.4126 - accuracy: 0.8247 - val_loss: 0.6239 - val_accuracy: 0.7905
# Epoch 16/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.4541 - accuracy: 0.7935 - val_loss: 0.6187 - val_accuracy: 0.7568
# Epoch 17/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.4120 - accuracy: 0.8295 - val_loss: 0.5906 - val_accuracy: 0.7500
# Epoch 18/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.4194 - accuracy: 0.8247 - val_loss: 0.5791 - val_accuracy: 0.7703
# Epoch 19/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3774 - accuracy: 0.8379 - val_loss: 0.6439 - val_accuracy: 0.7568
# Epoch 20/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.4021 - accuracy: 0.8271 - val_loss: 0.6453 - val_accuracy: 0.7703
# Epoch 21/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.3648 - accuracy: 0.8439 - val_loss: 0.6718 - val_accuracy: 0.7770
# Epoch 22/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3313 - accuracy: 0.8547 - val_loss: 0.6908 - val_accuracy: 0.7568
# Epoch 23/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.3632 - accuracy: 0.8523 - val_loss: 0.6875 - val_accuracy: 0.7365
# Epoch 24/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3650 - accuracy: 0.8451 - val_loss: 0.5868 - val_accuracy: 0.7973
# Epoch 25/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3448 - accuracy: 0.8451 - val_loss: 0.7482 - val_accuracy: 0.7635
# Epoch 26/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.3616 - accuracy: 0.8295 - val_loss: 0.7715 - val_accuracy: 0.7770
# Epoch 27/50
# 119/119 [==============================] - 2s 13ms/step - loss: 0.3613 - accuracy: 0.8571 - val_loss: 0.6422 - val_accuracy: 0.7905
# Epoch 28/50
# 119/119 [==============================] - 1s 11ms/step - loss: 0.3549 - accuracy: 0.8283 - val_loss: 0.7149 - val_accuracy: 0.7838
# Epoch 29/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3307 - accuracy: 0.8439 - val_loss: 0.6660 - val_accuracy: 0.7500
# Epoch 30/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3072 - accuracy: 0.8667 - val_loss: 0.7661 - val_accuracy: 0.7838
# Epoch 31/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3201 - accuracy: 0.8391 - val_loss: 0.8715 - val_accuracy: 0.7500
# Epoch 32/50
# 119/119 [==============================] - 2s 17ms/step - loss: 0.3180 - accuracy: 0.8439 - val_loss: 0.9470 - val_accuracy: 0.7838
# Epoch 33/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3428 - accuracy: 0.8511 - val_loss: 0.6929 - val_accuracy: 0.7838
# Epoch 34/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3088 - accuracy: 0.8523 - val_loss: 0.8320 - val_accuracy: 0.7905
# Epoch 35/50
# 119/119 [==============================] - 2s 18ms/step - loss: 0.2782 - accuracy: 0.8715 - val_loss: 0.9104 - val_accuracy: 0.7500
# Epoch 36/50
# 119/119 [==============================] - 2s 18ms/step - loss: 0.2966 - accuracy: 0.8727 - val_loss: 0.9116 - val_accuracy: 0.7568
# Epoch 37/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3203 - accuracy: 0.8631 - val_loss: 0.9146 - val_accuracy: 0.7500
# Epoch 38/50
# 119/119 [==============================] - 2s 18ms/step - loss: 0.3009 - accuracy: 0.8547 - val_loss: 0.9955 - val_accuracy: 0.7500
# Epoch 39/50
# 119/119 [==============================] - 2s 16ms/step - loss: 0.2968 - accuracy: 0.8607 - val_loss: 0.8545 - val_accuracy: 0.7703
# Epoch 40/50
# 119/119 [==============================] - 2s 18ms/step - loss: 0.2845 - accuracy: 0.8667 - val_loss: 1.0570 - val_accuracy: 0.7500
# Epoch 41/50
# 119/119 [==============================] - 2s 16ms/step - loss: 0.2764 - accuracy: 0.8643 - val_loss: 0.8953 - val_accuracy: 0.7770
# Epoch 42/50
# 119/119 [==============================] - 2s 16ms/step - loss: 0.2830 - accuracy: 0.8643 - val_loss: 0.8501 - val_accuracy: 0.7568
# Epoch 43/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.3037 - accuracy: 0.8607 - val_loss: 0.8094 - val_accuracy: 0.7568
# Epoch 44/50
# 119/119 [==============================] - 2s 13ms/step - loss: 0.2710 - accuracy: 0.8547 - val_loss: 0.9761 - val_accuracy: 0.7500
# Epoch 45/50
# 119/119 [==============================] - 2s 17ms/step - loss: 0.2834 - accuracy: 0.8679 - val_loss: 0.9601 - val_accuracy: 0.7365
# Epoch 46/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2799 - accuracy: 0.8727 - val_loss: 0.9290 - val_accuracy: 0.7568
# Epoch 47/50
# 119/119 [==============================] - 2s 15ms/step - loss: 0.2707 - accuracy: 0.8631 - val_loss: 1.0668 - val_accuracy: 0.7635
# Epoch 48/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2828 - accuracy: 0.8679 - val_loss: 0.9886 - val_accuracy: 0.7500
# Epoch 49/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2612 - accuracy: 0.8800 - val_loss: 0.8482 - val_accuracy: 0.7568
# Epoch 50/50
# 119/119 [==============================] - 2s 14ms/step - loss: 0.2505 - accuracy: 0.8715 - val_loss: 0.8486 - val_accuracy: 0.7568

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test Loss:', score[0])
print('Test accuracy:', score[1])

test_image = X_test[0:1]
print (test_image.shape)

print(model.predict(test_image))
print(model.predict_classes(test_image))
print(y_test[0:1])

res = model.predict_classes(X_test[9:18])
plt.figure(figsize=(10, 10))

for i in range(0, 9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_test[i],cmap=plt.get_cmap('gray'))
    plt.gca().get_xaxis().set_ticks([])
    plt.gca().get_yaxis().set_ticks([])
    plt.ylabel('prediction = %s' % getLabel(res[i]), fontsize=14)
# show the plot
plt.show()
# Out:
# Test Loss: 0.8485643267631531
# Test accuracy: 0.7567567825317383
# (1, 48, 48, 3)
# [[9.0747958e-01 8.9496173e-02 2.8320912e-03 9.9872828e-05 5.3171207e-05
#   2.2794870e-06 3.6809797e-05]]
# WARNING:tensorflow:From <ipython-input-12-786948e3f431>:9: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# [0]
# [[1. 0. 0. 0. 0. 0. 0.]]

# %%
# visualizing losses and accuracy
# %matplotlib inline

train_loss=hist.history['loss']
val_loss=hist.history['val_loss']
train_acc=hist.history['acc']
val_acc=hist.history['val_acc']

epochs = range(len(train_acc))

plt.plot(epochs,train_loss,'r', label='train_loss')
plt.plot(epochs,val_loss,'b', label='val_loss')
plt.title('train_loss vs val_loss')
plt.legend()
plt.figure()

plt.plot(epochs,train_acc,'r', label='train_acc')
plt.plot(epochs,val_acc,'b', label='val_acc')
plt.title('train_acc vs val_acc')
plt.legend()
plt.figure()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-35087fdbf52b> in <module>
#       4 train_loss=hist.history['loss']
#       5 val_loss=hist.history['val_loss']
# ----> 6 train_acc=hist.history['acc']
#       7 val_acc=hist.history['val_acc']
#       8
#
# KeyError: 'acc'
